# %%
import pandas as pd

# %%
df = pd.read_csv('UK house prices.csv')

# %%
df
# Out:
#               Date                         Region_Name  Area_Code  \
# 0       01/04/1968                               Wales  W92000004
# 1       01/04/1968                            Scotland  S92000003
# 2       01/04/1968                    Northern Ireland  N92000001
# 3       01/04/1968                             England  E92000001
# 4       01/04/1968            Yorkshire and The Humber  E12000003
# ...            ...                                 ...        ...
# 132030  01/10/2020                      Northumberland  E06000057
# 132031  01/10/2020  Bournemouth Christchurch and Poole  E06000058
# 132032  01/10/2020                   England and Wales  K04000001
# 132033  01/10/2020                       Great Britain  K03000001
# 132034  01/10/2020                      United Kingdom  K02000001
#
#         Average_Price  Monthly_Change  Annual_Change  Average_Price_SA
# 0         2885.414162        0.000000            NaN               NaN
# ...

# %%
df.describe()
# Out:
#        Average_Price  Monthly_Change  Annual_Change  Average_Price_SA
# count   1.320350e+05   131580.000000  126851.000000       4314.000000
# mean    1.617993e+05        0.561308       6.483759     151820.600318
# std     1.082149e+05        2.012154       9.101430      77182.433524
# min     2.712016e+03      -30.297781     -35.786566      40405.313840
# 25%     9.017127e+04       -0.455880       1.286862     100867.083275
# 50%     1.429300e+05        0.515821       5.353649     145306.053250
# 75%     2.037730e+05        1.521709      10.740076     189346.676000
# max     1.463378e+06       35.286646      98.437940     493189.631000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132035 entries, 0 to 132034
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              132035 non-null  object
#  1   Region_Name       132035 non-null  object
#  2   Area_Code         132035 non-null  object
#  3   Average_Price     132035 non-null  float64
#  4   Monthly_Change    131580 non-null  float64
#  5   Annual_Change     126851 non-null  float64
#  6   Average_Price_SA  4314 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 7.1+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Date                     0
# Region_Name              0
# Area_Code                0
# Average_Price            0
# Monthly_Change         455
# Annual_Change         5184
# Average_Price_SA    127721
# dtype: int64

# %%
df.loc[df.Monthly_Change.isnull()]
# Out:
#              Date               Region_Name  Area_Code  Average_Price  \
# 9      01/04/1968            United Kingdom  K02000001    3594.602239
# 3309   01/01/1995                     Wales  W92000004   43164.308270
# 3312   01/01/1995                   England  E92000001   53202.771280
# 3313   01/01/1995              Outer London  E13000002   72958.798360
# 3314   01/01/1995              Inner London  E13000001   78251.976500
# ...           ...                       ...        ...            ...
# 51109  01/03/2005       Fermanagh and Omagh  N09000006  104874.980200
# 51112  01/03/2005   Derry City and Strabane  N09000005   94944.041150
# 51115  01/03/2005  Causeway Coast and Glens  N09000004  120121.322200
# 51127  01/03/2005     Newry Mourne and Down  N09000010  113420.880200
# 51128  01/03/2005       Ards and North Down  N09000011  130398.569700
#
#        Monthly_Change  Annual_Change  Average_Price_SA
# 9                 NaN            NaN               NaN
# ...

# %%
df.Region_Name.value_counts()
# Out:
# Region_Name
# Wales                                  631
# Northern Ireland                       631
# England                                631
# Yorkshire and The Humber               631
# East Midlands                          631
#                                       ...
# Newry Mourne and Down                  190
# Fermanagh and Omagh                    190
# Armagh City Banbridge and Craigavon    190
# Antrim and Newtownabbey                190
# Causeway Coast and Glens               190
# Name: count, Length: 431, dtype: int64

# %%
df.sort_values(by=['Region_Name', 'Date'])
# Out:
#               Date               Region_Name  Area_Code  Average_Price  \
# 45115   01/01/2004             Aberdeenshire  S12000034    81693.66964
# 50153   01/01/2005             Aberdeenshire  S12000034   101818.93310
# 55345   01/01/2006             Aberdeenshire  S12000034   111351.61130
# 60526   01/01/2007             Aberdeenshire  S12000034   145371.47530
# 65674   01/01/2008             Aberdeenshire  S12000034   173220.42830
# ...            ...                       ...        ...            ...
# 106642  01/12/2015  Yorkshire and The Humber  E12000003   145530.52990
# 111795  01/12/2016  Yorkshire and The Humber  E12000003   152583.42480
# 116971  01/12/2017  Yorkshire and The Humber  E12000003   158435.41610
# 122145  01/12/2018  Yorkshire and The Humber  E12000003   162130.21910
# 127325  01/12/2019  Yorkshire and The Humber  E12000003   165750.83690
#
#         Monthly_Change  Annual_Change  Average_Price_SA
# 45115              NaN            NaN               NaN
# ...

# %%
df = df[df.columns[:4]]
df.head()
# Out:
#          Date               Region_Name  Area_Code  Average_Price
# 0  01/04/1968                     Wales  W92000004    2885.414162
# 1  01/04/1968                  Scotland  S92000003    2844.980688
# 2  01/04/1968          Northern Ireland  N92000001    3661.485500
# 3  01/04/1968                   England  E92000001    3408.108064
# 4  01/04/1968  Yorkshire and The Humber  E12000003    2712.015577

# %%
df = df.drop(['Area_Code'], axis=1)
df.head()
# Out:
#          Date               Region_Name  Average_Price
# 0  01/04/1968                     Wales    2885.414162
# 1  01/04/1968                  Scotland    2844.980688
# 2  01/04/1968          Northern Ireland    3661.485500
# 3  01/04/1968                   England    3408.108064
# 4  01/04/1968  Yorkshire and The Humber    2712.015577

# %%
df.groupby('Region_Name')[['Average_Price']].mean()
# Out:
#                           Average_Price
# Region_Name
# Aberdeenshire             168762.813121
# Adur                      185964.555459
# Allerdale                 109713.431032
# Amber Valley              113940.380121
# Angus                     128205.483404
# ...                                 ...
# Wycombe                   245717.859460
# Wyre                      117325.309602
# Wyre Forest               130884.883798
# York                      160769.553049
# Yorkshire and The Humber   64737.338917
#
# [431 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.dtypes
# Out:
# Date              object
# Region_Name       object
# Average_Price    float64
# dtype: object

# %%
df.to_csv("UK_Housing_Data.csv")
